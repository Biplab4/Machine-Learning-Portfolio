# %% [markdown]
# <a href="https://colab.research.google.com/github/Biplab4/Machine-Learning-Portfolio/blob/main/Deep%20Learning/convolutional_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip "/content/drive/MyDrive/CNN_Project/S37 - dataset.zip" -d "/content/drive/MyDrive/CNN_Project/"
# Out:
# Archive:  /content/drive/MyDrive/CNN_Project/S37 - dataset.zip
# replace /content/drive/MyDrive/CNN_Project/__MACOSX/._dataset? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory(
    '/content/drive/MyDrive/CNN_Project/dataset/training_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory(
    '/content/drive/MyDrive/CNN_Project/dataset/test_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
cnn = tf.keras.models.Sequential()

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 107s 281ms/step - accuracy: 0.5631 - loss: 0.6844 - val_accuracy: 0.6690 - val_loss: 0.6220
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 119s 333ms/step - accuracy: 0.6676 - loss: 0.6117 - val_accuracy: 0.7025 - val_loss: 0.5747
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 72s 286ms/step - accuracy: 0.7010 - loss: 0.5703 - val_accuracy: 0.6950 - val_loss: 0.5789
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 72s 289ms/step - accuracy: 0.7221 - loss: 0.5403 - val_accuracy: 0.7350 - val_loss: 0.5243
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 73s 294ms/step - accuracy: 0.7445 - loss: 0.5134 - val_accuracy: 0.7520 - val_loss: 0.5230
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 73s 292ms/step - accuracy: 0.7539 - loss: 0.4978 - val_accuracy: 0.7540 - val_loss: 0.5004
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 73s 293ms/step - accuracy: 0.7625 - loss: 0.4810 - val_accuracy: 0.7805 - val_loss: 0.4880
# Epoch 8/25
# ...

# %%
# Updated with the correct filename you found
img_path = '/content/drive/MyDrive/CNN_Project/dataset/single_prediction/cat.4001.jpg'

test_image = image.load_img(img_path, target_size=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)

# Run the prediction
result = cnn.predict(test_image)

# Output the result
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'

print(f"The model predicts: {prediction}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# The model predicts: dog
